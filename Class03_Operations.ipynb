# %% [markdown]
# <a href="https://colab.research.google.com/github/nooruluzair/Modern-AI-Python-Programming-Panaversity/blob/main/Class03_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Class 03: 101-P003**

# %%
num1 : int = 3
num2 : float = 3.2

# %%
print(5/4)
# Out:
# 1.25

# %% [markdown]
# 1. Mutable (Can be changed)
# 2. Immutables (can not be chaned)

# %%
# int & float are immutable type
# -5 to 255 (Interning -> int)
# id()

# %%
any_number : int = 260  # any_number declare
print(id(any_number))
any_number = 370
print(id(any_number))
# Out:
# 138095845425296
# 138095845427504

# %%
any_variable : int = 5
print(any_variable)
# Out:
# 5

# %%
a: int = 10
b: int = 3
print("a + b  = ", a + b)   # 13 Addition
print("a - b  = ", a - b)   # 7 Subtraction
print("a * b  = ", a * b)   # 30 Multiplication
print("a / b  = ", a / b)   # 3.3333333333333335
print("a // b = ", a // b)  # 3 Floor Division
print("a % b  = ", a % b)   # 1 Modulus (remainder)
print("a ** b  = ", a ** b)  # 1000 Exponentiation (10 * 10 * 10)
print("a ** b  = ", b ** a) # ()
# Out:
# a + b  =  13
# a - b  =  7
# a * b  =  30
# a / b  =  3.3333333333333335
# a // b =  3
# a % b  =  1
# a ** b  =  1000
# a ** b  =  59049

# %%
print(5%3)
# Out:
# 2

# %%
c: int = 10
d: str = "name"

print(c+d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2429825435.py in <cell line: 0>()
#       2 d: str = "name"
#       3
# ----> 4 print(c+d)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
e = 10
f = "name"

print(e+f)

# %%
print(5 + 3.4)
print(5 - 3.4)
print(5 * 4) # int
print(5 * 3.4) # float
print(10 / 2) # float
# Out:
# 8.4
# 1.6
# 20
# 17.0
# 5.0

# %%
print(10 / 2) # result will be float
# Out:
# 4.761904761904762

# %%
print(11 // 2)
# Out:
# 5

# %%
print(-7 // 2 )
# Out:
# -4

# %%
print(-7 % 2)
# Out:
# 1

# %%
print(7 % -2)
# Out:
# -1

# %%
print(-7 % -2)
# Out:
# -1

# %%
print( 9 * 'Rehan')
# Out:
# RehanRehanRehanRehanRehanRehanRehanRehanRehan

# %%
a = 5
a = a + 3

# %% [markdown]
# ## String
# - Immutable (more than 20  characters)
# - "asdlfds", 'dfdsfads', """adsfdfds """, '''5'''  --> string

# %%
sentence: str = "My name is Rehan"
print(sentence)
# Out:
# My name is Rehan

# %%
print(type(sentence))
# Out:
# <class 'str'>

# %%
sentence = "This is Rehan's house"

# Triple quotes are used for multiline string

# %%
sentence = '''This is Rehan
house
Hello
Ammar
'''

# %%
'''This is Rehan
house
Hello
Ammar
'''
# This is a single line comment

# %%
# \ is an escape character
sentence = "This is Rehan \
house"
print(sentence)
# Out:
# This is Rehan house

# %%
total_secnds = 3454546
# H : M : S
print(total_secnds // 3600)
# Out:
# 959
